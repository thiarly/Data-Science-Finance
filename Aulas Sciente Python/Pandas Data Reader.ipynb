# %% [markdown]
# # Bibliotecas

# %%
import pandas_datareader.data as web
from datetime import datetime

# %%
start = datetime(2019, 1, 1)
end = datetime (2020, 1, 1)

# %% [markdown]
# # PIP

# %%
gdp = web.DataReader('GDP', 'fred', start, end)
gdp

# %%
gdp = web.Dat

# %% [markdown]
# # INFLAÇÃO

# %%
# Multiple series:
cpi = web.DataReader('CPIAUCSL', 'fred', start)
cpi

# %% [markdown]
# # Treasury Bonds

# %% [markdown]
# # 3 Meses

# %%
t3mo = web.DataReader('DGS3MO', 'fred', start)
t3mo

# %% [markdown]
# # 10 Anos

# %%
t10 = web.DataReader('DGS10', 'fred', start)
t10

# %% [markdown]
# # Emprego

# %% [markdown]
# # Taxa de Desemprego

# %%
desemprego = web.DataReader('UNRATE', 'fred', start)
desemprego

# %% [markdown]
# # Pessoas empregadas

# %%
empregos = web.DataReader('PAYEMS', 'fred', start)
empregos

# %% [markdown]
# # Agregado M2 (Papel moeda, depósitos à bista e à prazo)

# %%
m2 = web.DataReader('M2', 'fred', start)
m2

# %% [markdown]
# # Ativos do FED

# %%
ativos = web.DataReader('WALCL', 'fred', start)
ativos
