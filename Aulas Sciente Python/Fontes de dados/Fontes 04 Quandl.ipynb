# %% [markdown]
# # Quandl

# %%
# !pip install -q quandl

# %%
import quandl

# %% [markdown]
# # API KEY

# %%
quandl.ApiConfig.api_key = 'fh8M8UzjrLxaQC1o4LsH'

# %% [markdown]
# ## Consultas

# %%
cape = quandl.get("MULTPL/SHILLER_PE_RATIO_MONTH")
cape
# Out:
#             Value
# Date
# 1871-02-01  10.92
# 1871-03-01  11.19
# 1871-04-01  12.05
# 1871-05-01  12.59
# 1871-06-01  12.59
# ...           ...
# 2021-03-01  35.05
# 2021-03-31  35.74
# 2021-04-01  36.50
# 2021-04-30  37.56
# 2021-05-01  37.49
#
# [1818 rows x 1 columns]

# %%
ipca = quandl.get('BCB/433')
ipca
# Out:
#             Value
# Date
# 1980-01-31   6.62
# 1980-02-29   4.62
# 1980-03-31   6.04
# 1980-04-30   5.29
# 1980-05-31   5.70
# ...           ...
# 2020-11-30   0.89
# 2020-12-31   1.35
# 2021-01-31   0.25
# 2021-02-28   0.86
# 2021-03-31   0.93
#
# [495 rows x 1 columns]

# %%
acucar = quandl.get('CEPEA/SUGAR_C')
acucar
# Out:
#             Price US$  Daily %  Monthly %
# Date
# 2013-01-23      22.02      NaN        NaN
# 2013-01-24      21.91      NaN        NaN
# 2013-01-25      22.02      NaN        NaN
# 2013-01-28      22.07      NaN        NaN
# 2013-01-29      22.38      NaN        NaN
# ...               ...      ...        ...
# 2021-05-05      20.75     1.52       2.02
# 2021-05-06      21.01     1.25       3.29
# 2021-05-07      21.12     0.52       3.83
# 2021-05-10      21.50     1.80       5.70
# 2021-05-11      21.38    -0.56       5.11
#
# [2052 rows x 3 columns]

# %%
big_mac = quandl.get('ECONOMIST/BIGMAC_BRA')
big_mac
# Out:
#             local_price  dollar_ex  ...  yen_adj_valuation  yuan_adj_valuation
# Date                                ...
# 2000-04-30         2.95    1.79000  ...                NaN                 NaN
# 2001-04-30         3.60    2.19000  ...                NaN                 NaN
# 2002-04-30         3.60    2.34000  ...                NaN                 NaN
# 2003-04-30         4.55    3.07000  ...                NaN                 NaN
# 2004-05-31         5.40    3.18000  ...                NaN                 NaN
# 2005-06-30         5.90    2.46480  ...                NaN                 NaN
# 2006-01-31         6.20    2.26150  ...                NaN                 NaN
# 2006-05-31         6.40    2.30450  ...                NaN                 NaN
# 2007-01-31         6.40    2.13350  ...                NaN                 NaN
# 2007-06-30         6.90    1.91300  ...                NaN                 NaN
# ...

# %%
btc = quandl.get('BCHAIN/MKPRU')
btc
# Out:
#                Value
# Date
# 2009-01-02      0.00
# 2009-01-03      0.00
# 2009-01-04      0.00
# 2009-01-05      0.00
# 2009-01-06      0.00
# ...              ...
# 2021-05-08  57380.27
# 2021-05-09  58928.81
# 2021-05-10  58280.73
# 2021-05-11  55883.50
# 2021-05-12  56750.00
#
# [4514 rows x 1 columns]
