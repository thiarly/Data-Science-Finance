# %% [markdown]
# # Nova seção
# ## Nova seção
#
# isso é um texto markdown
#
# 1. Item da lista
# 2. Item da lista

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.8/112.8 KB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 34.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.9.3
#     Uninstalling beautifulsoup4-4.9.3:
# ...

# %%
import yfinance as yf

# %%
yf.download('BVSP')
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BVSP: No timezone found, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
frutas [1] = 'uva'

# %%
print ('texto')
# Out:
# texto

# %%
import pandas as pd

# %%
pd.read_excel('/content/drive/MyDrive/Multas.xlsx')

# %%
frutas = ['maça', 'banana', 'laranja', 'pera']

# %%
numeros = [1, 2, 3, 4, 5]

# %%
frutas.append('melancia')

# %%
frutas.pop(0)

# %%
frutas

# %%
len(frutas)

# %%
frutas

# %%
numeros

# %%
frutas + numeros + [True, False, False] + [10, 20, 30]

# %%
marcas = ('gm', 'ford', 'fiat', 'vw')

# %%
marcas

# %%
cores = ('amarelo', 'vermelho', 'branco', 'preto')

# %%
cores

# %%
marcas [1:3]

# %%
notas = {'português':8, 'ingles':7.4, 'matematica':9}

# %%
notas ['ingles']

# %%
notas ['fisica'] = 8.5

# %%
notas

# %%
listes = [1,2,3,'cachorro','gato','papagaio']

# %%
for itens in listes:
  print(itens)

# %%
cont = [0,1,2,3,4,5]

# %%
cont
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
for c in cont:
  print(c)

# %%
for c in range(50):
  print (c)

# %%
i = 0
while True:
  print(i)
  i += 1
  if i >= 5:
    print ('Lotado')
    break

# %%
def ao_quadrado(numero):
  quad = numero ** 2
  return quad

# %%
ao_quadrado(3)
# Out:
# 9
